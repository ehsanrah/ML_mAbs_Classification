# %% [markdown]
# <h3 style='color:purple' align='center'>Decission Tree classification of absorption of monoclonal antibodies (mAbs) </h3>

# %% [markdown]
# <img src="mAbs.jpg" width="500" height="600" />

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# **Obtaining data**

# %%
data = pd.read_csv('mAbs.csv')
data
# Out:
#        Drug Name  Dose(mg) Injection method Injection site  AUC ratio  \
# 0     Alirocumab      75.0               AI    Arm/Abdomen       0.92
# 1     Alirocumab      75.0               AI  Thigh/Abdomen       0.84
# 2     Ixekizumab     160.0              PFS    Arm/Abdomen       1.12
# 3     Ixekizumab     160.0              PFS  Thigh/Abdomen       1.41
# 4     Ixekizumab     160.0               AI    Arm/Abdomen       0.78
# 5     Ixekizumab     160.0               AI  Thigh/Abdomen       1.12
# 6   Benralizumab      30.0              PFS    Arm/Abdomen       1.02
# 7   Benralizumab      30.0              PFS  Thigh/Abdomen       1.29
# 8   Benralizumab      30.0               AI    Arm/Abdomen       1.05
# 9   Benralizumab      30.0               AI  Thigh/Abdomen       1.20
# 10   Bococizumab     150.0          Syringe    Arm/Abdomen       0.95
# 11   Bococizumab     150.0          Syringe  Thigh/Abdomen       1.21
# 12   Trastuzumab     600.0          Syringe  Thigh/Abdomen       1.29
# 13    Adalimumab      40.0              PFS  Thigh/Abdomen       1.07
# 14    Adalimumab      40.0               AI  Thigh/Abdomen       1.12
# 15     Golimumab     100.0              PFS    Arm/Abdomen       1.11
# 16     Golimumab     100.0              PFS  Thigh/Abdomen       1.15
# 17   Tocilizumab     162.0              PFS    Arm/Abdomen       1.00
# 18   Tocilizumab     162.0              PFS  Thigh/Abdomen       1.10
# 19     Belimumab     200.0              PFS  Thigh/Abdomen       1.17
# 20     Belimumab     200.0               AI  Thigh/Abdomen       1.08
# 21   Canakinumab     150.0              PFS  Thigh/Abdomen       1.04
# 22   Canakinumab     150.0               AI  Thigh/Abdomen       1.03
# 23   Secukinumab     300.0          Syringe  Thigh/Abdomen       1.17
# 24   Mepolizumab     250.0          Syringe    Arm/Abdomen       1.12
# 25   Mepolizumab     250.0          Syringe  Thigh/Abdomen       1.08
# 26    Emicizumab      70.0          Syringe    Arm/Abdomen       0.93
# 27    Emicizumab      70.0          Syringe  Thigh/Abdomen       1.07
# 28  Galcanezumab     120.0              PFS    Arm/Abdomen       0.97
# 29  Galcanezumab     120.0              PFS  Thigh/Abdomen       1.22
# 30  Galcanezumab     120.0               AI    Arm/Abdomen       1.03
# 31  Galcanezumab     120.0               AI  Thigh/Abdomen       1.06
# 32   Lanadelumab     300.0          Syringe    Arm/Abdomen       1.03
# 33   Lanadelumab     300.0          Syringe  Thigh/Abdomen       1.14
# 34   Tezepelumab     210.0              PFS    Arm/Abdomen       1.05
# 35   Tezepelumab     210.0              PFS  Thigh/Abdomen       1.22
# 36   Tezepelumab     210.0               AI    Arm/Abdomen       0.87
# 37   Tezepelumab     210.0               AI  Thigh/Abdomen       0.94
# 38         mab A       NaN              PFS  Thigh/Abdomen       1.14
# 39         mab B       NaN              PFS    Arm/Abdomen       0.86
# 40         mab B       NaN              PFS  Thigh/Abdomen       1.06
# 41         mab B       NaN               AI    Arm/Abdomen       1.04
# 42         mab B       NaN               AI  Thigh/Abdomen       1.24
# 43         mab C       NaN              PFS    Arm/Abdomen       0.85
# 44         mab C       NaN              PFS  Thigh/Abdomen       1.14
# 45         mab C       NaN               AI    Arm/Abdomen       1.02
# 46         mab C       NaN               AI  Thigh/Abdomen       0.97
#
#     Cmax Ratio  Tmax Ratio
# 0         0.79        2.35
# 1         0.88        1.03
# 2         1.13         NaN
# 3         1.46         NaN
# 4         0.75         NaN
# 5         1.14         NaN
# 6         0.95         NaN
# 7         1.52         NaN
# 8         0.94         NaN
# 9         1.30         NaN
# 10        0.86         NaN
# 11        1.28         NaN
# 12        1.29        1.00
# 13        1.11        1.27
# 14        1.02        1.33
# 15        0.80        1.00
# 16        1.08        1.25
# 17         NaN         NaN
# 18         NaN         NaN
# 19        1.11        1.05
# 20        1.13        0.90
# 21        1.19        0.99
# 22        1.04        1.00
# 23        1.16        0.79
# 24        1.02        0.71
# 25        1.12        0.71
# 26        0.82        1.64
# 27        1.17        1.22
# 28        1.05        1.29
# 29        1.13        0.72
# 30        1.01        1.29
# 31        0.93        0.71
# 32        1.04        1.01
# 33        1.14        1.01
# 34        0.92        0.99
# 35        1.19        1.00
# 36        0.82        1.20
# 37        0.96        1.38
# 38        1.13         NaN
# 39        0.84        1.00
# 40        1.09        0.71
# 41        0.92        1.28
# 42        1.16        0.71
# 43        0.82         NaN
# 44        1.11         NaN
# 45        0.97         NaN
# 46        0.88         NaN

# %% [markdown]
# **Defining the target:**
# In this project if the AUC ratio of Arm or Thigh are greater than Abdomen, the taget is 1, otherwise is zero**

# %%
data['target'] = np.where(data['AUC ratio'] > 1.2, 3, np.where(data['AUC ratio'] > 1.0 ,2, np.where(data['AUC ratio'] > 0.8, 1, 0) ))

# %%
data.head()
# Out:
#     Drug Name  Dose(mg) Injection method Injection site  AUC ratio  \
# 0  Alirocumab      75.0               AI    Arm/Abdomen       0.92
# 1  Alirocumab      75.0               AI  Thigh/Abdomen       0.84
# 2  Ixekizumab     160.0              PFS    Arm/Abdomen       1.12
# 3  Ixekizumab     160.0              PFS  Thigh/Abdomen       1.41
# 4  Ixekizumab     160.0               AI    Arm/Abdomen       0.78
#
#    Cmax Ratio  Tmax Ratio  target
# 0        0.79        2.35       1
# 1        0.88        1.03       1
# 2        1.13         NaN       2
# 3        1.46         NaN       3
# 4        0.75         NaN       0

# %% [markdown]
# **Before training the model we should encode labels to numbers**

# %%
from sklearn.preprocessing import LabelEncoder
le_Injection_method = LabelEncoder()
le_Injection_site = LabelEncoder()

# %%
data['Encoded Injection method'] = le_Injection_method.fit_transform(data['Injection method'])
data['Encoded Injection site'] = le_Injection_site.fit_transform(data['Injection site'])
data.head(15)
# Out:
#        Drug Name  Dose(mg) Injection method Injection site  AUC ratio  \
# 0     Alirocumab      75.0               AI    Arm/Abdomen       0.92
# 1     Alirocumab      75.0               AI  Thigh/Abdomen       0.84
# 2     Ixekizumab     160.0              PFS    Arm/Abdomen       1.12
# 3     Ixekizumab     160.0              PFS  Thigh/Abdomen       1.41
# 4     Ixekizumab     160.0               AI    Arm/Abdomen       0.78
# 5     Ixekizumab     160.0               AI  Thigh/Abdomen       1.12
# 6   Benralizumab      30.0              PFS    Arm/Abdomen       1.02
# 7   Benralizumab      30.0              PFS  Thigh/Abdomen       1.29
# 8   Benralizumab      30.0               AI    Arm/Abdomen       1.05
# 9   Benralizumab      30.0               AI  Thigh/Abdomen       1.20
# 10   Bococizumab     150.0          Syringe    Arm/Abdomen       0.95
# 11   Bococizumab     150.0          Syringe  Thigh/Abdomen       1.21
# 12   Trastuzumab     600.0          Syringe  Thigh/Abdomen       1.29
# 13    Adalimumab      40.0              PFS  Thigh/Abdomen       1.07
# 14    Adalimumab      40.0               AI  Thigh/Abdomen       1.12
#
#     Cmax Ratio  Tmax Ratio  target  Encoded Injection method  \
# 0         0.79        2.35       1                         0
# 1         0.88        1.03       1                         0
# 2         1.13         NaN       2                         1
# 3         1.46         NaN       3                         1
# 4         0.75         NaN       0                         0
# 5         1.14         NaN       2                         0
# 6         0.95         NaN       2                         1
# 7         1.52         NaN       3                         1
# 8         0.94         NaN       2                         0
# 9         1.30         NaN       2                         0
# 10        0.86         NaN       1                         2
# 11        1.28         NaN       3                         2
# 12        1.29        1.00       3                         2
# 13        1.11        1.27       2                         1
# 14        1.02        1.33       2                         0
#
#     Encoded Injection site
# 0                        0
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# 5                        1
# 6                        0
# 7                        1
# 8                        0
# 9                        1
# 10                       0
# 11                       1
# 12                       1
# 13                       1
# 14                       1

# %% [markdown]
# **Train and the model and prediction**

# %%
X = data[["Encoded Injection method","Encoded Injection site"]]
y = data.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.4

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([2, 2, 2, 3, 2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 2])

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[0, 3, 0],
#        [0, 6, 3],
#        [0, 3, 0]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
